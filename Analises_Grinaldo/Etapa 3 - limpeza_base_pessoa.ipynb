# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/bootcamp/Averiguacao Cadastral/Dados
# Out:
# /content/drive/MyDrive/bootcamp/Averiguacao Cadastral/Dados

# %%
import pandas as pd

# %%
# Load the datasets
df_pessoas_amostra_100mil = pd.read_csv('df_pessoas_amostra_para_limpeza.csv', sep=',', dtype={23: 'str'})

# %%
df_pessoas_amostra_100mil.head()
# Out:
#    id_familia  id_pessoa  cod_sexo_pessoa  idade  cod_parentesco_rf_pessoa  \
# 0     1230168          5                2     13                         3
# 1     3850635          6                2     11                         3
# 2     1271681         10                2     21                         1
# 3     5101918         13                2      0                         3
# 4     4148669         14                2      7                         4
#
#    cod_raca_cor_pessoa  cod_local_nascimento_pessoa  \
# 0                  4.0                          2.0
# 1                  4.0                          1.0
# 2                  4.0                          2.0
# 3                  1.0                          1.0
# 4                  1.0                          1.0
#
#    cod_certidao_registrada_pessoa  cod_deficiencia_memb  \
# 0                               1                     2
# 1                               1                     2
# 2                               1                     2
# 3                               1                     2
# 4                               1                     2
#
#    cod_sabe_ler_escrever_memb  ...  cod_curso_frequentou_pessoa_memb  \
# 0                         1.0  ...                               NaN
# 1                         2.0  ...                               NaN
# 2                         1.0  ...                               NaN
# 3                         2.0  ...                               NaN
# 4                         2.0  ...                               NaN
#
#    cod_ano_serie_frequentou_memb  cod_concluiu_frequentou_memb  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
#
#    cod_trabalhou_memb  cod_afastado_trab_memb  cod_agricultura_trab_memb  \
# 0                 NaN                     NaN                        NaN
# 1                 NaN                     NaN                        NaN
# 2                 2.0                     2.0                        NaN
# 3                 NaN                     NaN                        NaN
# 4                 NaN                     NaN                        NaN
#
#    cod_principal_trab_memb  cod_trabalho_12_meses_memb  \
# 0                      NaN                         NaN
# 1                      NaN                         NaN
# 2                      NaN                         2.0
# 3                      NaN                         NaN
# 4                      NaN                         NaN
#
#    qtd_meses_12_meses_memb         peso.pes
# 0                      NaN  563268298617514
# 1                      NaN  563281304029541
# 2                      NaN  563276153365714
# 3                      NaN  563276393161791
# 4                      NaN  563270632129414
#
# [5 rows x 24 columns]

# %%
df_pessoas_amostra_100mil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8020234 entries, 0 to 8020233
# Data columns (total 24 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   id_familia                        int64
#  1   id_pessoa                         int64
#  2   cod_sexo_pessoa                   int64
#  3   idade                             int64
#  4   cod_parentesco_rf_pessoa          int64
#  5   cod_raca_cor_pessoa               float64
#  6   cod_local_nascimento_pessoa       float64
#  7   cod_certidao_registrada_pessoa    int64
#  8   cod_deficiencia_memb              int64
#  9   cod_sabe_ler_escrever_memb        float64
#  10  ind_frequenta_escola_memb         float64
#  11  cod_escola_local_memb             float64
#  12  cod_curso_frequenta_memb          float64
#  13  cod_ano_serie_frequenta_memb      float64
#  14  cod_curso_frequentou_pessoa_memb  float64
#  15  cod_ano_serie_frequentou_memb     float64
#  16  cod_concluiu_frequentou_memb      float64
#  17  cod_trabalhou_memb                float64
#  18  cod_afastado_trab_memb            float64
#  19  cod_agricultura_trab_memb         float64
#  20  cod_principal_trab_memb           float64
#  21  cod_trabalho_12_meses_memb        float64
#  22  qtd_meses_12_meses_memb           float64
#  23  peso.pes                          object
# dtypes: float64(16), int64(7), object(1)
# memory usage: 1.4+ GB

# %%
df_familia_filtrado = df_pessoas_amostra_100mil[df_pessoas_amostra_100mil['id_familia'] == 1]

print(df_familia_filtrado)
# Out:
#          id_familia  id_pessoa  cod_sexo_pessoa  idade  \
# 26407             1      42351                2     21
# 2719864           1    4357243                1     50
# 5573501           1    8931078                2     43
# 5726186           1    9176057                2     15
# 7468283           1   11967511                2     18
#
#          cod_parentesco_rf_pessoa  cod_raca_cor_pessoa  \
# 26407                           3                  4.0
# 2719864                         2                  4.0
# 5573501                         1                  4.0
# 5726186                         3                  4.0
# 7468283                         3                  4.0
#
#          cod_local_nascimento_pessoa  cod_certidao_registrada_pessoa  \
# 26407                            2.0                               2
# 2719864                          2.0                               1
# 5573501                          2.0                               1
# 5726186                          2.0                               2
# 7468283                          2.0                               2
#
#          cod_deficiencia_memb  cod_sabe_ler_escrever_memb  ...  \
# 26407                       2                         1.0  ...
# 2719864                     2                         1.0  ...
# 5573501                     2                         1.0  ...
# 5726186                     2                         1.0  ...
# 7468283                     2                         1.0  ...
#
#          cod_curso_frequentou_pessoa_memb  cod_ano_serie_frequentou_memb  \
# 26407                                 8.0                            3.0
# 2719864                               5.0                            5.0
# 5573501                               5.0                            6.0
# 5726186                               NaN                            NaN
# 7468283                               8.0                            3.0
#
#          cod_concluiu_frequentou_memb  cod_trabalhou_memb  \
# 26407                             1.0                 1.0
# 2719864                           2.0                 2.0
# 5573501                           2.0                 1.0
# 5726186                           NaN                 2.0
# 7468283                           1.0                 2.0
#
#          cod_afastado_trab_memb  cod_agricultura_trab_memb  \
# 26407                       NaN                        2.0
# 2719864                     2.0                        NaN
# 5573501                     NaN                        2.0
# 5726186                     2.0                        NaN
# 7468283                     2.0                        NaN
#
#          cod_principal_trab_memb  cod_trabalho_12_meses_memb  \
# 26407                        4.0                         1.0
# 2719864                      NaN                         2.0
# 5573501                      1.0                         1.0
# 5726186                      NaN                         2.0
# 7468283                      NaN                         2.0
#
#          qtd_meses_12_meses_memb         peso.pes
# 26407                       12.0  563284518618848
# 2719864                      NaN  563284518618848
# 5573501                     12.0  563284518618848
# 5726186                      NaN  563284518618848
# 7468283                      NaN  563284518618848
#
# [5 rows x 24 columns]

# %%
# Identificar IDs de pessoa que se repetem
ids_repetidos = df_pessoas_amostra_100mil['id_pessoa'][df_pessoas_amostra_100mil['id_pessoa'].duplicated()]

# Verificar se existem IDs repetidos e exibir o resultado
if not ids_repetidos.empty:
    print(f'Existem IDs de pessoa repetidos. Os IDs repetidos são:\n{ids_repetidos}')
else:
    print('Não existem IDs de pessoa repetidos.')
# Out:
# Existem IDs de pessoa repetidos. Os IDs repetidos são:
# 373812     6
# 623888     1
# 1872434    3
# 2496973    4
# 3120770    5
# 3745072    6
# 4993271    8
# 5616602    9
# 6239891    1
# Name: id_pessoa, dtype: int64

# %%
df_pessoas_amostra_100mil.describe()
# Out:
#          id_familia     id_pessoa  cod_sexo_pessoa         idade  \
# count  8.020234e+06  8.020234e+06     8.020234e+06  8.020234e+06
# mean   2.658008e+06  6.425676e+06     1.568728e+00  2.681394e+01
# std    1.519553e+06  3.710342e+06     4.952540e-01  2.032950e+01
# min    1.000000e+00  1.000000e+00     1.000000e+00  0.000000e+00
# 25%    1.364204e+06  3.212068e+06     1.000000e+00  1.000000e+01
# 50%    2.660591e+06  6.424690e+06     2.000000e+00  2.200000e+01
# 75%    3.970992e+06  9.639293e+06     2.000000e+00  4.100000e+01
# max    5.290701e+06  1.285260e+07     2.000000e+00  1.300000e+02
#
#        cod_parentesco_rf_pessoa  cod_raca_cor_pessoa  \
# count              8.020234e+06         8.017041e+06
# mean               2.329500e+00         3.045310e+00
# std                1.452148e+00         1.354827e+00
# min                1.000000e+00         1.000000e+00
# 25%                1.000000e+00         1.000000e+00
# 50%                3.000000e+00         4.000000e+00
# 75%                3.000000e+00         4.000000e+00
# max                1.100000e+01         5.000000e+00
#
#        cod_local_nascimento_pessoa  cod_certidao_registrada_pessoa  \
# count                 7.986305e+06                    8.020234e+06
# mean                  1.440720e+00                    1.097475e+00
# std                   5.029306e-01                    2.969504e-01
# min                   1.000000e+00                    1.000000e+00
# 25%                   1.000000e+00                    1.000000e+00
# 50%                   1.000000e+00                    1.000000e+00
# 75%                   2.000000e+00                    1.000000e+00
# max                   3.000000e+00                    4.000000e+00
#
#        cod_deficiencia_memb  cod_sabe_ler_escrever_memb  ...  \
# count          8.020234e+06                8.019038e+06  ...
# mean           1.949397e+00                1.255197e+00  ...
# std            2.191862e-01                4.359720e-01  ...
# min            1.000000e+00                1.000000e+00  ...
# 25%            2.000000e+00                1.000000e+00  ...
# 50%            2.000000e+00                1.000000e+00  ...
# 75%            2.000000e+00                2.000000e+00  ...
# max            2.000000e+00                2.000000e+00  ...
#
#        cod_ano_serie_frequenta_memb  cod_curso_frequentou_pessoa_memb  \
# count                  2.188086e+06                      4.167799e+06
# mean                   4.300159e+00                      6.200731e+00
# std                    2.555050e+00                      2.140484e+00
# min                    1.000000e+00                      1.000000e+00
# 25%                    2.000000e+00                      4.000000e+00
# 50%                    4.000000e+00                      5.000000e+00
# 75%                    6.000000e+00                      8.000000e+00
# max                    1.000000e+01                      1.500000e+01
#
#        cod_ano_serie_frequentou_memb  cod_concluiu_frequentou_memb  \
# count                   3.964740e+06                  3.964873e+06
# mean                    4.004091e+00                  1.499833e+00
# std                     2.087258e+00                  5.000000e-01
# min                     1.000000e+00                  1.000000e+00
# 25%                     3.000000e+00                  1.000000e+00
# 50%                     3.000000e+00                  1.000000e+00
# 75%                     5.000000e+00                  2.000000e+00
# max                     1.000000e+01                  2.000000e+00
#
#        cod_trabalhou_memb  cod_afastado_trab_memb  cod_agricultura_trab_memb  \
# count        5.335660e+06            3.565153e+06               1.770523e+06
# mean         1.668175e+00            1.985818e+00               1.752079e+00
# std          4.708687e-01            1.182396e-01               4.318056e-01
# min          1.000000e+00            1.000000e+00               1.000000e+00
# 25%          1.000000e+00            2.000000e+00               2.000000e+00
# 50%          2.000000e+00            2.000000e+00               2.000000e+00
# 75%          2.000000e+00            2.000000e+00               2.000000e+00
# max          2.000000e+00            2.000000e+00               2.000000e+00
#
#        cod_principal_trab_memb  cod_trabalho_12_meses_memb  \
# count             1.821067e+06                5.334731e+06
# mean              2.252712e+00                1.638591e+00
# std               1.936325e+00                4.804088e-01
# min               1.000000e+00                1.000000e+00
# 25%               1.000000e+00                1.000000e+00
# 50%               1.000000e+00                2.000000e+00
# 75%               4.000000e+00                2.000000e+00
# max               1.100000e+01                2.000000e+00
#
#        qtd_meses_12_meses_memb
# count             1.928015e+06
# mean              8.713296e+00
# std               4.067429e+00
# min               1.000000e+00
# 25%               5.000000e+00
# 50%               1.200000e+01
# 75%               1.200000e+01
# max               1.200000e+01
#
# [8 rows x 23 columns]

# %%
# Mostrando os valores nulos de cada coluna do DataFrame
valores_nulos = df_pessoas_amostra_100mil.isna().sum()

# Exibindo os resultados
print("Número de valores nulos em cada coluna:")
print(valores_nulos[valores_nulos > 0])  # Exibe apenas as colunas com valores nulos
# Out:
# Número de valores nulos em cada coluna:
# cod_raca_cor_pessoa                    3193
# cod_local_nascimento_pessoa           33929
# cod_sabe_ler_escrever_memb             1196
# ind_frequenta_escola_memb              1236
# cod_escola_local_memb               5307105
# cod_curso_frequenta_memb            5286748
# cod_ano_serie_frequenta_memb        5832148
# cod_curso_frequentou_pessoa_memb    3852435
# cod_ano_serie_frequentou_memb       4055494
# cod_concluiu_frequentou_memb        4055361
# cod_trabalhou_memb                  2684574
# cod_afastado_trab_memb              4455081
# cod_agricultura_trab_memb           6249711
# cod_principal_trab_memb             6199167
# cod_trabalho_12_meses_memb          2685503
# qtd_meses_12_meses_memb             6092219
# dtype: int64

# %%
#como os campos relacionadas à escola que a pessoa frequenta só devem ser preenchidos caso
# a pessoa frequente escola, ou seja, tenha respondido 1 - Sim, rede pública, 2 - Sim, rede particular
# para a variável  ind_frequenta_escola_memb, identificar os campos sem preenchimento ligados a respostas
# diferentes de 1 e 2

# Filtrando os casos em que 'ind_frequenta_escola_memb' seja diferente de 1 ou de 2
filtro = df_pessoas_amostra_100mil[
    (df_pessoas_amostra_100mil['ind_frequenta_escola_memb'] != 1) &
    (df_pessoas_amostra_100mil['ind_frequenta_escola_memb'] != 2)
]

# Lista das colunas que queremos exibir os resultados
colunas_interesse = ["cod_escola_local_memb",
    "cod_curso_frequenta_memb",
    "cod_ano_serie_frequenta_memb"
]

# Exibe os valores únicos de cada coluna filtrada
for coluna in colunas_interesse:
    valores_unicos = filtro[coluna].unique()
    print(f"Coluna: {coluna}")
    print(f"Valores únicos: {valores_unicos}")
    print("-" * 40)
# Out:
# Coluna: cod_escola_local_memb
# Valores únicos: [nan]
# ----------------------------------------
# Coluna: cod_curso_frequenta_memb
# Valores únicos: [nan]
# ----------------------------------------
# Coluna: cod_ano_serie_frequenta_memb
# Valores únicos: [nan]
# ----------------------------------------

# %%
#Considerando a regra de preenchimento das variáveis relacionadas à escola que frequenta, que só são obrigatórias
# se a variável "ind_frequenta_escola_memb" for respondida como 1 - Sim, rede pública, 2 - Sim, rede particular,
# quando preenchimento != 1 & != 2 as variáveis relacionadas à escola que frequenta foram preenchidas
#como -1

import numpy as np

# Lista das colunas a serem preenchidas
cols_to_fill = ["cod_escola_local_memb",
    "cod_curso_frequenta_memb",
    "cod_ano_serie_frequenta_memb"
]

# Condição: "ind_frequenta_escola_memb" diferente de 1 e de 2
cond = (df_pessoas_amostra_100mil['ind_frequenta_escola_memb'] != 1) & \
    (df_pessoas_amostra_100mil['ind_frequenta_escola_memb'] != 2)

# Preenchendo os valores NaN com -1 nas colunas especificadas quando a condição for atendida
df_pessoas_amostra_100mil.loc[cond, cols_to_fill] = df_pessoas_amostra_100mil.loc[cond, cols_to_fill].fillna(-1)

# Verificar se os valores foram preenchidos corretamente
print(df_pessoas_amostra_100mil[cols_to_fill].isna().sum())  # Verifica a ausência de valores nulos
# Out:
# cod_escola_local_memb            20672
# cod_curso_frequenta_memb           315
# cod_ano_serie_frequenta_memb    545715
# dtype: int64

# %%
#Como o campo cod_ano_serie_frequenta_memb (ano e série que a pessoa frequente) só deve
# ser preenchido se pessoa frequenta algum dos cursos  4 - Ensino Fundamental regular (duração 8 anos),
# 5 - Ensino Fundamental regular (duração 9 anos), 6 - Ensino Fundamental especial,
# 7 - Ensino Médio regular ou 8 - Ensino Médio especial da pergunta cod_curso_frequenta_memb
# (curso que a pessoa frequenta), avaliar os casos de NaN do campo cod_ano_serie_frequenta_memb
# quando o campo cod_ano_serie_frequenta_memb é Nan.

# Filtrando os casos onde 'cod_ano_serie_frequenta_memb' é NaN
filtro_nan = df_pessoas_amostra_100mil['cod_ano_serie_frequenta_memb'].isna()

# Contando os valores de 'cod_curso_frequenta_memb' para os casos onde 'cod_ano_serie_frequenta_memb' é NaN
tipos_resposta = df_pessoas_amostra_100mil.loc[filtro_nan, 'cod_curso_frequenta_memb'].value_counts()

# Ordenando os resultados pelos índices (os próprios valores de 'cod_curso_frequenta_memb')
tipos_resposta = tipos_resposta.sort_index()

# Exibindo os tipos de resposta e suas quantidades
print("Tipos de respostas e suas quantidades para 'cod_curso_frequenta_memb' quando 'cod_ano_serie_frequenta_memb' é NaN:")
print(tipos_resposta)
# Out:
# Tipos de respostas e suas quantidades para 'cod_curso_frequenta_memb' quando 'cod_ano_serie_frequenta_memb' é NaN:
# cod_curso_frequenta_memb
# 1.0     163682
# 2.0     205500
# 3.0      48723
# 5.0          2
# 7.0          1
# 9.0       8461
# 10.0     39940
# 11.0     25631
# 12.0       700
# 13.0     52450
# 14.0       310
# Name: count, dtype: int64

# %%
#Considerando que todos os casos de Nan do campo cod_ano_serie_frequenta_memb se referem
# aos casos em que não é obrigatória a resposta, ou seja, diferente de 4, 5, 6, 7 ou 8,
# os valores NaN serão substituídos por -1

# Substituindo valores NaN na coluna 'cod_ano_serie_frequenta_memb' por -1
df_pessoas_amostra_100mil['cod_ano_serie_frequenta_memb'].fillna(-1, inplace=True)

# Contando os valores da coluna 'cod_ano_serie_frequenta_memb' após a substituição
respostas_quantidade_depois = df_pessoas_amostra_100mil['cod_ano_serie_frequenta_memb'].value_counts()

# Exibindo todas as respostas possíveis e a quantidade de cada uma após a substituição
print("\nQuantidade de cada resposta na coluna 'cod_ano_serie_frequenta_memb' após a substituição de NaN por -1:")
# Out:
# Quantidade de cada resposta na coluna 'cod_ano_serie_frequenta_memb' após a substituição de NaN por -1:

# %%
#como o preenchimento do campo 'cod_curso_frequentou_pessoa_memb'
# (Curso mais elevado que a pessoa frequentou) só é obrigatório quando
# o campo 'ind_frequenta_escola_memb' (Pessoa frequenta escola?) for respondido como
# "3 - Não, já frequentou", avaliar as respostas de 'cod_curso_frequentou_pessoa_memb'
# quando 'ind_frequenta_escola_memb' for diferente de 3

# Filtrando os casos em que 'ind_frequenta_escola_memb' seja diferente de 3
filtro = df_pessoas_amostra_100mil[(df_pessoas_amostra_100mil['ind_frequenta_escola_memb'] != 3)]

# Lista da coluna a exibir os resultados
coluna_interesse = ['cod_curso_frequentou_pessoa_memb']

# Exibe o valor único de cada coluna filtrada
for coluna in coluna_interesse:
    valores_unicos = filtro[coluna].unique()
    print(f"Coluna: {coluna}")
    print(f"Valores únicos: {valores_unicos}")
# Out:
# Coluna: cod_curso_frequentou_pessoa_memb
# Valores únicos: [nan]

# %%
#Considerando a regra de preenchimento das variáveis relacionadas ao curso que frequentou, que só é obrigatório
# se a variável "ind_frequenta_escola_memb" for respondida como "3 - Não, já frequentou",
# quando preenchimento != 3 a variável relacionada ao curso que frequentou foi preenchida como -1

# Lista da coluna a ser preenchida
col_to_fill = ["cod_curso_frequentou_pessoa_memb"]

# Condição: "ind_frequenta_escola_memb" diferente de 3
cond = (df_pessoas_amostra_100mil['ind_frequenta_escola_memb'] != 3)

# Preenchendo os valores NaN com -1 na coluna especificada quando a condição for atendida
df_pessoas_amostra_100mil.loc[cond, col_to_fill] = df_pessoas_amostra_100mil.loc[cond, col_to_fill].fillna(-1)

# %%
# Contando a frequência de cada valor único na coluna 'cod_curso_frequentou_pessoa_memb', incluindo NaN
frequencia_respostas = df_pessoas_amostra_100mil['cod_curso_frequentou_pessoa_memb'].value_counts(dropna=False)

# Ordenando os resultados pelos índices (os próprios valores de 'cod_curso_frequentou_pessoa_memb')
frequencia_respostas = frequencia_respostas.sort_index()

# Exibindo os valores únicos e suas frequências
print("Frequência de cada resposta na coluna 'cod_curso_frequentou_pessoa_memb', ordenada pelos valores:")
print(frequencia_respostas)
# Out:
# Frequência de cada resposta na coluna 'cod_curso_frequentou_pessoa_memb', ordenada pelos valores:
# cod_curso_frequentou_pessoa_memb
# -1.0     3852050
#  1.0        2908
#  2.0        2768
#  3.0       28145
#  4.0     1116826
#  5.0     1063863
#  6.0      198635
#  7.0       19702
#  8.0     1535815
#  9.0       29954
#  10.0      17749
#  11.0      32589
#  12.0      20113
#  13.0      86643
#  14.0       6946
#  15.0       5143
#  NaN         385
# Name: count, dtype: int64

# %%
#como os campos cod_ano_serie_frequentou_memb e cod_concluiu_frequentou_memb só devem ser preenchidos caso
# a pessoa frequentou algum dos cursos 4 - Ensino Fundamental 1ª a 4ª séries, Elementar (Primário), Primeira fase do 1º grau,
# 5 - Ensino Fundamental 5ª a 8ª séries, Médio 1º ciclo (Ginasial), Segunda fase do 1º grau,
# 6 - Ensino Fundamental (duração 9 anos), 7 - Ensino Fundamental Especial,
# 8 - Ensino Médio, 2º grau, Médio 2º ciclo (Científico, Clássico, Técnico, Normal),
# 9 - Ensino Médio Especial na questão anterior (cod_curso_frequentou_pessoa_memb),
# identificar os campos sem preenchimento ligados a respostas do campo anterior:

# Filtrando os casos em que 'cod_curso_frequentou_pessoa_memb' seja diferente de 4, 5, 6, 7, 8 ou 9
filtro = df_pessoas_amostra_100mil[
    (df_pessoas_amostra_100mil['cod_curso_frequentou_pessoa_memb'] != 4) &
    (df_pessoas_amostra_100mil['cod_curso_frequentou_pessoa_memb'] != 5) &
    (df_pessoas_amostra_100mil['cod_curso_frequentou_pessoa_memb'] != 6) &
    (df_pessoas_amostra_100mil['cod_curso_frequentou_pessoa_memb'] != 7) &
    (df_pessoas_amostra_100mil['cod_curso_frequentou_pessoa_memb'] != 8) &
    (df_pessoas_amostra_100mil['cod_curso_frequentou_pessoa_memb'] != 9)
]

# Lista das colunas que queremos exibir os resultados
colunas_interesse = ["cod_ano_serie_frequentou_memb",
    "cod_concluiu_frequentou_memb"
]

# Exibe os valores únicos de cada coluna filtrada
for coluna in colunas_interesse:
    valores_unicos = filtro[coluna].value_counts(dropna=False)
    print(f"Coluna: {coluna}")
    print(f"Frequência de valores únicos:\n{valores_unicos}")
    print("-" * 40)
# Out:
# Coluna: cod_ano_serie_frequentou_memb
# Frequência de valores únicos:
# cod_ano_serie_frequentou_memb
# NaN    4055360
# 3.0         19
# 4.0         14
# 1.0         13
# 2.0          8
# 8.0          7
# 5.0          7
# 6.0          5
# 7.0          5
# 9.0          1
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: cod_concluiu_frequentou_memb
# Frequência de valores únicos:
# cod_concluiu_frequentou_memb
# NaN    4055360
# 2.0         49
# 1.0         30
# Name: count, dtype: int64
# ----------------------------------------

# %%
# Lista das colunas que queremos substituir os valores NaN por -1
colunas_para_substituir = ["cod_ano_serie_frequentou_memb", "cod_concluiu_frequentou_memb"]

# Definindo a condição para quando 'cod_curso_frequentou_pessoa_memb' não for 4, 5, 6, 7, 8 ou 9
condicao = (
    (df_pessoas_amostra_100mil['cod_curso_frequentou_pessoa_memb'] != 4) &
    (df_pessoas_amostra_100mil['cod_curso_frequentou_pessoa_memb'] != 5) &
    (df_pessoas_amostra_100mil['cod_curso_frequentou_pessoa_memb'] != 6) &
    (df_pessoas_amostra_100mil['cod_curso_frequentou_pessoa_memb'] != 7) &
    (df_pessoas_amostra_100mil['cod_curso_frequentou_pessoa_memb'] != 8) &
    (df_pessoas_amostra_100mil['cod_curso_frequentou_pessoa_memb'] != 9)
)

# Substituindo os valores NaN por -1 nas colunas especificadas quando a condição é atendida
df_pessoas_amostra_100mil.loc[condicao, colunas_para_substituir] = df_pessoas_amostra_100mil.loc[condicao, colunas_para_substituir].fillna(-1)

# Verificando se os valores foram preenchidos corretamente
print("Valores substituídos nas colunas:")
for coluna in colunas_para_substituir:
    print(f"{coluna} - Valores únicos: {df_pessoas_amostra_100mil[coluna].unique()}")
# Out:
# Valores substituídos nas colunas:
# cod_ano_serie_frequentou_memb - Valores únicos: [-1.  4.  5.  3.  8.  1.  6.  2.  7. 10.  9. nan]
# cod_concluiu_frequentou_memb - Valores únicos: [-1.  1.  2. nan]

# %%
# Mostrando os valores nulos de cada coluna do DataFrame após limpeza
valores_nulos = df_pessoas_amostra_100mil.isna().sum()

# Exibindo os resultados
print("Número de valores nulos em cada coluna:")
print(valores_nulos[valores_nulos > 0])  # Exibe apenas as colunas com valores nulos
# Out:
# Número de valores nulos em cada coluna:
# cod_raca_cor_pessoa                    3193
# cod_local_nascimento_pessoa           33929
# cod_sabe_ler_escrever_memb             1196
# ind_frequenta_escola_memb              1236
# cod_escola_local_memb                 20672
# cod_curso_frequenta_memb                315
# cod_curso_frequentou_pessoa_memb        385
# cod_ano_serie_frequentou_memb           134
# cod_concluiu_frequentou_memb              1
# cod_trabalhou_memb                  2684574
# cod_afastado_trab_memb              4455081
# cod_agricultura_trab_memb           6249711
# cod_principal_trab_memb             6199167
# cod_trabalho_12_meses_memb          2685503
# qtd_meses_12_meses_memb             6092219
# dtype: int64

# %%
#Os campos de trabalho só devem ser respondidos quando idade for maior ou igual a 14 anos. Desta forma, avaliar
# o preenchimento dos campos "cod_trabalhou_memb", "cod_afastado_trab_memb", "cod_agricultura_trab_memb",
# "cod_principal_trab_memb", "cod_trabalho_12_meses_memb", "qtd_meses_12_meses_memb", "categoria_qtd_meses" com idade
# menor que 14 anos

# Filtrando os casos em que 'idade' seja < 14
filtro = (df_pessoas_amostra_100mil['idade'] < 14)

# Lista das colunas que queremos exibir os resultados
colunas_interesse = [
    "cod_trabalhou_memb",
    "cod_afastado_trab_memb",
    "cod_agricultura_trab_memb",
    "cod_principal_trab_memb",
    "cod_trabalho_12_meses_memb",
    "qtd_meses_12_meses_memb",
]

# Exibe os valores únicos de cada coluna filtrada
for coluna in colunas_interesse:
    # Filtrando o DataFrame pelas linhas onde 'idade' < 14 e obtendo as contagens de valores
    valores_unicos = df_pessoas_amostra_100mil.loc[filtro, coluna].value_counts(dropna=False)
    print(f"Coluna: {coluna}")
    print(f"Frequência de valores únicos:\n{valores_unicos}")
    print("-" * 40)
# Out:
# Coluna: cod_trabalhou_memb
# Frequência de valores únicos:
# cod_trabalhou_memb
# NaN    2665095
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: cod_afastado_trab_memb
# Frequência de valores únicos:
# cod_afastado_trab_memb
# NaN    2665095
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: cod_agricultura_trab_memb
# Frequência de valores únicos:
# cod_agricultura_trab_memb
# NaN    2665095
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: cod_principal_trab_memb
# Frequência de valores únicos:
# cod_principal_trab_memb
# NaN    2665095
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: cod_trabalho_12_meses_memb
# Frequência de valores únicos:
# cod_trabalho_12_meses_memb
# NaN    2665095
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: qtd_meses_12_meses_memb
# Frequência de valores únicos:
# qtd_meses_12_meses_memb
# NaN    2665095
# Name: count, dtype: int64
# ----------------------------------------

# %%
#Substituir todos os valores nan por -1 das colunas avaliadas quando idade <14

# Filtrando os casos em que 'idade' seja < 14
filtro = (df_pessoas_amostra_100mil['idade'] < 14)

# Lista das colunas nas quais queremos substituir os NaN
colunas_interesse = [
    "cod_trabalhou_memb",
    "cod_afastado_trab_memb",
    "cod_agricultura_trab_memb",
    "cod_principal_trab_memb",
    "cod_trabalho_12_meses_memb",
    "qtd_meses_12_meses_memb"]

# Substituindo os valores NaN por -1 nas colunas de interesse quando a condição do filtro é verdadeira
df_pessoas_amostra_100mil.loc[filtro, colunas_interesse] = df_pessoas_amostra_100mil.loc[filtro, colunas_interesse].fillna(-1)

# Mostrando os valores nulos de cada coluna do DataFrame após limpeza
valores_nulos = df_pessoas_amostra_100mil.isna().sum()

# Exibindo os resultados
print("Número de valores nulos em cada coluna:")
print(valores_nulos[valores_nulos > 0])  # Exibe apenas as colunas com valores nulos
# Out:
# Número de valores nulos em cada coluna:
# cod_raca_cor_pessoa                    3193
# cod_local_nascimento_pessoa           33929
# cod_sabe_ler_escrever_memb             1196
# ind_frequenta_escola_memb              1236
# cod_escola_local_memb                 20672
# cod_curso_frequenta_memb                315
# cod_curso_frequentou_pessoa_memb        385
# cod_ano_serie_frequentou_memb           134
# cod_concluiu_frequentou_memb              1
# cod_trabalhou_memb                    19479
# cod_afastado_trab_memb              1789986
# cod_agricultura_trab_memb           3584616
# cod_principal_trab_memb             3534072
# cod_trabalho_12_meses_memb            20408
# qtd_meses_12_meses_memb             3427124
# dtype: int64

# %%
# O campo 'cod_afastado_trab_memb' só deve ser respondido se 'cod_trabalhou_memb'
# (Pessoa trabalhou na semana passada?) for respondido como 2 - Não)

# Filtrando os casos em que 'cod_trabalhou_memb' seja diferente de 2
filtro = df_pessoas_amostra_100mil[(df_pessoas_amostra_100mil['cod_trabalhou_memb'] != 2)]

# Lista da coluna a exibir os resultados
coluna_interesse = 'cod_afastado_trab_memb'

# Contando os valores, incluindo NaN
valores_contagem = filtro[coluna_interesse].value_counts(dropna=False)  # dropna=False inclui NaN

# Exibindo o resultado
print(f"Frequência de valores para '{coluna_interesse}' quando 'cod_trabalhou_memb' não é 2:")
print(valores_contagem)
# Out:
# Frequência de valores para 'cod_afastado_trab_memb' quando 'cod_trabalhou_memb' não é 2:
# cod_afastado_trab_memb
# -1.0    2665095
#  NaN    1789985
#  2.0          2
# Name: count, dtype: int64

# %%
# Substituir os valores NaN de 'cod_afastado_trab_memb' por -1 quando 'cod_trabalhou_memb' é diferente de 2

# Lista da coluna a ser preenchida
col_to_fill = ["cod_afastado_trab_memb"]

# Condição: "ind_frequenta_escola_memb" diferente de 3
cond = (df_pessoas_amostra_100mil['cod_trabalhou_memb'] != 2)

# Preenchendo os valores NaN com -1 na coluna especificada quando a condição for atendida
df_pessoas_amostra_100mil.loc[cond, col_to_fill] = df_pessoas_amostra_100mil.loc[cond, col_to_fill].fillna(-1)

# %%
# O campo cod_agricultura_trab_memb (É atividade extrativista? 1 - Sim e 2 - Não) e o campo
# cod_principal_trab_memb só são obrigatórios se a pessoa respondeu 1 - Sim no campo
# cod_trabalhou_memb (Pessoa trabalhou na semana passada?)
# ou cod_afastado_trab_memb (Pessoa afastada na semana passada?).

# Filtrando os casos em que campo 'cod_trabalhou_memb' e 'cod_afastado_trab_memb' seja diferente de 1
filtro = df_pessoas_amostra_100mil[
    (df_pessoas_amostra_100mil['cod_trabalhou_memb'] != 1) &
    (df_pessoas_amostra_100mil['cod_afastado_trab_memb'] != 1)
]

# Lista das colunas que queremos exibir os resultados
colunas_interesse = ["cod_agricultura_trab_memb",
"cod_principal_trab_memb"]

# Exibe os valores únicos de cada coluna filtrada
for coluna in colunas_interesse:
    valores_unicos = filtro[coluna].value_counts(dropna=False)
    print(f"Coluna: {coluna}")
    print(f"Frequência de valores únicos:\n{valores_unicos}")
    print("-" * 40)
# Out:
# Coluna: cod_agricultura_trab_memb
# Frequência de valores únicos:
# cod_agricultura_trab_memb
#  NaN    3534056
# -1.0    2665095
#  1.0         15
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: cod_principal_trab_memb
# Frequência de valores únicos:
# cod_principal_trab_memb
#  NaN    3534071
# -1.0    2665095
# Name: count, dtype: int64
# ----------------------------------------

# %%
#Substituindo por -1 os valores NaN de "cod_agricultura_trab_memb" e "cod_principal_trab_memb"
# quando 'cod_trabalhou_memb' e 'cod_afastado_trab_memb' é diferente de 1

# Definindo o filtro para casos onde 'cod_trabalhou_memb' e 'cod_afastado_trab_memb' são diferentes de 1
filtro = (df_pessoas_amostra_100mil['cod_trabalhou_memb'] != 1) & (df_pessoas_amostra_100mil['cod_afastado_trab_memb'] != 1)

# Substituindo os valores NaN das colunas 'cod_agricultura_trab_memb' e 'cod_principal_trab_memb' por -1 onde o filtro é verdadeiro
df_pessoas_amostra_100mil.loc[filtro, 'cod_agricultura_trab_memb'] = df_pessoas_amostra_100mil.loc[filtro, 'cod_agricultura_trab_memb'].fillna(-1)
df_pessoas_amostra_100mil.loc[filtro, 'cod_principal_trab_memb'] = df_pessoas_amostra_100mil.loc[filtro, 'cod_principal_trab_memb'].fillna(-1)

# Exibindo os valores únicos de cada coluna após a substituição
valores_unicos_agricultura = df_pessoas_amostra_100mil['cod_agricultura_trab_memb'].value_counts(dropna=False)
valores_unicos_principal = df_pessoas_amostra_100mil['cod_principal_trab_memb'].value_counts(dropna=False)

print("Frequência de valores únicos na coluna 'cod_agricultura_trab_memb' após substituição de NaN por -1:")
print(valores_unicos_agricultura)
print("\nFrequência de valores únicos na coluna 'cod_principal_trab_memb' após substituição de NaN por -1:")
print(valores_unicos_principal)
# Out:
# Frequência de valores únicos na coluna 'cod_agricultura_trab_memb' após substituição de NaN por -1:
# cod_agricultura_trab_memb
# -1.0    6199151
#  2.0    1331574
#  1.0     438949
#  NaN      50560
# Name: count, dtype: int64
#
# Frequência de valores únicos na coluna 'cod_principal_trab_memb' após substituição de NaN por -1:
# cod_principal_trab_memb
# -1.0     6199166
#  1.0     1048846
#  4.0      320284
#  2.0      237696
#  3.0       56141
#  8.0       50308
#  7.0       42542
#  5.0       33087
#  6.0       16206
#  10.0       7612
#  11.0       7194
#  9.0        1151
#  NaN           1
# Name: count, dtype: int64

# %%
# Filtrando os casos onde 'cod_agricultura_trab_memb' é igual a NaN
filtro_cod_especie = df_pessoas_amostra_100mil['cod_agricultura_trab_memb'].isna()

# Contando os valores da coluna 'cod_principal_trab_memb' apenas para o filtro aplicado
resultados_quantidade = df_pessoas_amostra_100mil.loc[filtro_cod_especie, 'cod_principal_trab_memb'].value_counts(dropna=False)

# Ordenando os resultados em ordem crescente dos índices (valores únicos)
resultados_quantidade = resultados_quantidade.sort_index()

# Exibindo os resultados ordenados
print("Resultados possíveis e quantidade de cada resposta em 'cod_principal_trab_memb' quando 'cod_agricultura_trab_memb' é NaN:")
print(resultados_quantidade)
# Out:
# Resultados possíveis e quantidade de cada resposta em 'cod_principal_trab_memb' quando 'cod_agricultura_trab_memb' é NaN:
# cod_principal_trab_memb
# 1.0     22773
# 2.0     12849
# 3.0       884
# 4.0     10154
# 5.0       603
# 6.0       409
# 7.0      1771
# 8.0       933
# 9.0        23
# 10.0       63
# 11.0       97
# NaN         1
# Name: count, dtype: int64

# %%
# Considerando que a resposta de 'cod_principal_trab_memb' == 2 significa Trabalhador temporário em área rural
# Os casos de NaN para 'cod_agricultura_trab_memb' quando 'cod_principal_trab_memb' == 2 serão alterados
# para 1 - Sim. Os demais casos serão substituídos por 9 - Desconhecido.

# Definindo o filtro para casos onde 'cod_principal_trab_memb' é igual a 2
filtro = df_pessoas_amostra_100mil['cod_principal_trab_memb'] == 2

# Substituindo os valores NaN da coluna 'cod_agricultura_trab_memb' por 1 onde o filtro é verdadeiro
df_pessoas_amostra_100mil.loc[filtro, 'cod_agricultura_trab_memb'] = df_pessoas_amostra_100mil.loc[filtro, 'cod_agricultura_trab_memb'].fillna(1)

# Substituindo os valores NaN restantes por 9 nos casos onde o filtro é falso
df_pessoas_amostra_100mil['cod_agricultura_trab_memb'] = df_pessoas_amostra_100mil['cod_agricultura_trab_memb'].fillna(9)

# Exibindo os valores únicos da coluna após a substituição
valores_unicos_agricultura = df_pessoas_amostra_100mil['cod_agricultura_trab_memb'].value_counts(dropna=False)

print("Frequência de valores únicos na coluna 'cod_agricultura_trab_memb' após substituição de NaN:")
print(valores_unicos_agricultura)
# Out:
# Frequência de valores únicos na coluna 'cod_agricultura_trab_memb' após substituição de NaN:
# cod_agricultura_trab_memb
# -1.0    6199151
#  2.0    1331574
#  1.0     451798
#  9.0      37711
# Name: count, dtype: int64

# %%
# O campo qtd_meses_12_meses_memb (Quantidade de meses trabalhados nos últimos 12 meses)
# só é obrigatório se a pessoa tiver respondido 1 - Sim  no campo cod_trabalho_12_meses_memb
#(Pessoa com trabalho remunerado em algum período nos último 12 meses)

# Filtrando os casos em que campo 'cod_trabalho_12_meses_memb' seja diferente de 1
filtro = df_pessoas_amostra_100mil[
    (df_pessoas_amostra_100mil['cod_trabalho_12_meses_memb'] != 1)
]

# Lista da coluna que queremos exibir os resultados
coluna_interesse = ["qtd_meses_12_meses_memb"]

# Exibe os valores únicos de cada coluna filtrada
for coluna in coluna_interesse:
    valores_unicos = filtro[coluna].value_counts(dropna=False)
    print(f"Coluna: {coluna}")
    print(f"Frequência de valores únicos:\n{valores_unicos}")
    print("-" * 40)
# Out:
# Coluna: qtd_meses_12_meses_memb
# Frequência de valores únicos:
# qtd_meses_12_meses_memb
#  NaN    3427118
# -1.0    2665095
# Name: count, dtype: int64
# ----------------------------------------

# %%
#Substituindo por -1 os valores NaN de "qtd_meses_12_meses_memb"
# quando 'cod_trabalho_12_meses_memb' é diferente de 1

# Definindo o filtro para casos onde 'cod_trabalho_12_meses_memb' é diferente de 1
filtro = (df_pessoas_amostra_100mil['cod_trabalho_12_meses_memb'] != 1)

# Substituindo os valores NaN da coluna 'qtd_meses_12_meses_memb' por -1 onde o filtro é verdadeiro
df_pessoas_amostra_100mil.loc[filtro, 'qtd_meses_12_meses_memb'] = df_pessoas_amostra_100mil.loc[filtro, 'qtd_meses_12_meses_memb'].fillna(-1)


# Exibindo os valores únicos da coluna após a substituição
valores_unicos_meses = df_pessoas_amostra_100mil['qtd_meses_12_meses_memb'].value_counts(dropna=False)


print("Frequência de valores únicos na coluna 'qtd_meses_12_meses_memb' após substituição de NaN por -1:")
print(valores_unicos_meses)
# Out:
# Frequência de valores únicos na coluna 'qtd_meses_12_meses_memb' após substituição de NaN por -1:
# qtd_meses_12_meses_memb
# -1.0     6092213
#  12.0    1016425
#  1.0      126076
#  10.0     120692
#  6.0      120027
#  2.0      119812
#  3.0      113359
#  5.0       86775
#  4.0       80138
#  8.0       55436
#  7.0       37856
#  9.0       29555
#  11.0      21864
#  NaN           6
# Name: count, dtype: int64

# %%
# Mostrando os valores nulos de cada coluna do DataFrame após limpeza
valores_nulos = df_pessoas_amostra_100mil.isna().sum()

# Exibindo os resultados
print("Número de valores nulos em cada coluna:")
print(valores_nulos[valores_nulos > 0])  # Exibe apenas as colunas com valores nulos
# Out:
# Número de valores nulos em cada coluna:
# cod_raca_cor_pessoa                  3193
# cod_local_nascimento_pessoa         33929
# cod_sabe_ler_escrever_memb           1196
# ind_frequenta_escola_memb            1236
# cod_escola_local_memb               20672
# cod_curso_frequenta_memb              315
# cod_curso_frequentou_pessoa_memb      385
# cod_ano_serie_frequentou_memb         134
# cod_concluiu_frequentou_memb            1
# cod_trabalhou_memb                  19479
# cod_afastado_trab_memb                  1
# cod_principal_trab_memb                 1
# cod_trabalho_12_meses_memb          20408
# qtd_meses_12_meses_memb                 6
# dtype: int64

# %%
# Calculando o percentual de valores NaN em cada coluna
percentual_nan = df_pessoas_amostra_100mil.isna().mean() * 100

# Exibindo o percentual de valores NaN por coluna
print("Percentual de valores NaN em cada coluna do df_pessoas_amostra_100mil:")
print(percentual_nan)
# Out:
# Percentual de valores NaN em cada coluna do df_pessoas_amostra_100mil:
# id_familia                          0.000000
# id_pessoa                           0.000000
# cod_sexo_pessoa                     0.000000
# idade                               0.000000
# cod_parentesco_rf_pessoa            0.000000
# cod_raca_cor_pessoa                 0.039812
# cod_local_nascimento_pessoa         0.423043
# cod_certidao_registrada_pessoa      0.000000
# cod_deficiencia_memb                0.000000
# cod_sabe_ler_escrever_memb          0.014912
# ind_frequenta_escola_memb           0.015411
# cod_escola_local_memb               0.257748
# cod_curso_frequenta_memb            0.003928
# cod_ano_serie_frequenta_memb        0.000000
# cod_curso_frequentou_pessoa_memb    0.004800
# cod_ano_serie_frequentou_memb       0.001671
# cod_concluiu_frequentou_memb        0.000012
# cod_trabalhou_memb                  0.242873
# cod_afastado_trab_memb              0.000012
# cod_agricultura_trab_memb           0.000000
# cod_principal_trab_memb             0.000012
# cod_trabalho_12_meses_memb          0.254456
# qtd_meses_12_meses_memb             0.000075
# peso.pes                            0.000000
# dtype: float64

# %%
df_pessoas_amostra_100mil.shape
# Out:
# (8020234, 24)

# %%
# Considernado que as linhas com valores NaN remanescentes não foram associadas a nenhuma
# regra de preenchimento do cadastro único e que são pouco representativas no universo da
# amostra, optpu-se por excluir os valores NaN remanescentes da base de famílias

# Excluir todas as linhas com algum valor NaN
df_pessoas_amostra_100mil_limpa = df_pessoas_amostra_100mil.dropna()

# Mostrando os valores nulos de cada coluna do DataFrame após limpeza
valores_nulos = df_pessoas_amostra_100mil_limpa.isna().sum()

# Exibindo os resultados
print("Número de valores nulos em cada coluna:")
print(valores_nulos[valores_nulos > 0])  # Exibe apenas as colunas com valores nulos
# Out:
# Número de valores nulos em cada coluna:
# Series([], dtype: int64)

# %%
df_pessoas_amostra_100mil_limpa.shape
# Out:
# (7940902, 24)

# %%
# Identificar IDs de pessoa que se repetem
ids_repetidos = df_pessoas_amostra_100mil_limpa['id_pessoa'][df_pessoas_amostra_100mil_limpa['id_pessoa'].duplicated()]

# Verificar se existem IDs repetidos e exibir o resultado
if not ids_repetidos.empty:
    print(f'Existem IDs de pessoa repetidos. Os IDs repetidos são:\n{ids_repetidos}')
else:
    print('Não existem IDs de pessoa repetidos.')
# Out:
# Existem IDs de pessoa repetidos. Os IDs repetidos são:
# 373812     6
# 623888     1
# 1872434    3
# 2496973    4
# 3120770    5
# 3745072    6
# 4993271    8
# 5616602    9
# 6239891    1
# Name: id_pessoa, dtype: int64

# %%
# Load the datasets familia
df_fam_amostra_100mil_limpa = pd.read_csv('df_fam_amostra.csv')

# %%
df_fam_amostra_100mil_limpa.isna().sum()
# Out:
# cd_ibge                          0
# uf_ibge                          0
# regiao_ibge                      0
# estrato                          0
# classf                           0
# id_familia                       0
# vlr_renda_media_fam              0
# cod_local_domic_fam              0
# cod_especie_domic_fam            0
# qtd_comodos_domic_fam            0
# qtd_comodos_dormitorio_fam       0
# cod_material_piso_fam            0
# cod_material_domic_fam           0
# cod_agua_canalizada_fam          0
# cod_abaste_agua_domic_fam        0
# cod_banheiro_domic_fam           0
# cod_escoa_sanitario_domic_fam    0
# cod_destino_lixo_domic_fam       0
# cod_iluminacao_domic_fam         0
# cod_calcamento_domic_fam         0
# cod_familia_indigena_fam         0
# ind_familia_quilombola_fam       0
# ind_parc_mds_fam                 0
# qtde_pessoas                     0
# peso.fam                         0
# dias_cadastramento               0
# dias_atualizacao                 0
# classe_renda                     0
# dtype: int64

# %%
#juntando as duas bases
# Realizar o merge das duas bases usando a chave 'id_familia'
df_fam_pessoas_amostra_100mil_limpa = pd.merge(df_fam_amostra_100mil_limpa, df_pessoas_amostra_100mil_limpa,
                     on='id_familia',
                     how='inner')

# %%
df_fam_pessoas_amostra_100mil_limpa.shape
# Out:
# (7936814, 51)

# %%
df_fam_pessoas_amostra_100mil_limpa.head()
# Out:
#    cd_ibge  uf_ibge  regiao_ibge  estrato  classf  id_familia  \
# 0  4212908       42            4        1       2      268503
# 1  4212908       42            4        1       2      268503
# 2  4212908       42            4        1       2      268503
# 3  4212908       42            4        1       2      268503
# 4  2931905       29            2        2       3     2888440
#
#    vlr_renda_media_fam  cod_local_domic_fam  cod_especie_domic_fam  \
# 0                 60.0                  1.0                    1.0
# 1                 60.0                  1.0                    1.0
# 2                 60.0                  1.0                    1.0
# 3                 60.0                  1.0                    1.0
# 4                  0.0                  2.0                    1.0
#
#    qtd_comodos_domic_fam  ...  cod_curso_frequentou_pessoa_memb  \
# 0                    5.0  ...                              -1.0
# 1                    5.0  ...                              -1.0
# 2                    5.0  ...                              -1.0
# 3                    5.0  ...                               4.0
# 4                    2.0  ...                              -1.0
#
#    cod_ano_serie_frequentou_memb  cod_concluiu_frequentou_memb  \
# 0                           -1.0                          -1.0
# 1                           -1.0                          -1.0
# 2                           -1.0                          -1.0
# 3                            4.0                           1.0
# 4                           -1.0                          -1.0
#
#    cod_trabalhou_memb  cod_afastado_trab_memb  cod_agricultura_trab_memb  \
# 0                -1.0                    -1.0                       -1.0
# 1                 2.0                     2.0                       -1.0
# 2                -1.0                    -1.0                       -1.0
# 3                 1.0                    -1.0                        1.0
# 4                -1.0                    -1.0                       -1.0
#
#    cod_principal_trab_memb  cod_trabalho_12_meses_memb  \
# 0                     -1.0                        -1.0
# 1                     -1.0                         2.0
# 2                     -1.0                        -1.0
# 3                      6.0                         1.0
# 4                     -1.0                        -1.0
#
#    qtd_meses_12_meses_memb         peso.pes
# 0                     -1.0  563277716385694
# 1                     -1.0  563277716385694
# 2                     -1.0  563277716385694
# 3                     12.0  563277716385694
# 4                     -1.0  563263195326236
#
# [5 rows x 51 columns]

# %%
df_fam_pessoas_amostra_100mil_limpa.columns
# Out:
# Index(['cd_ibge', 'uf_ibge', 'regiao_ibge', 'estrato', 'classf', 'id_familia',
#        'vlr_renda_media_fam', 'cod_local_domic_fam', 'cod_especie_domic_fam',
#        'qtd_comodos_domic_fam', 'qtd_comodos_dormitorio_fam',
#        'cod_material_piso_fam', 'cod_material_domic_fam',
#        'cod_agua_canalizada_fam', 'cod_abaste_agua_domic_fam',
#        'cod_banheiro_domic_fam', 'cod_escoa_sanitario_domic_fam',
#        'cod_destino_lixo_domic_fam', 'cod_iluminacao_domic_fam',
#        'cod_calcamento_domic_fam', 'cod_familia_indigena_fam',
#        'ind_familia_quilombola_fam', 'ind_parc_mds_fam', 'qtde_pessoas',
#        'peso.fam', 'dias_cadastramento', 'dias_atualizacao', 'classe_renda',
#        'id_pessoa', 'cod_sexo_pessoa', 'idade', 'cod_parentesco_rf_pessoa',
#        'cod_raca_cor_pessoa', 'cod_local_nascimento_pessoa',
#        'cod_certidao_registrada_pessoa', 'cod_deficiencia_memb',
#        'cod_sabe_ler_escrever_memb', 'ind_frequenta_escola_memb',
#        'cod_escola_local_memb', 'cod_curso_frequenta_memb',
#        'cod_ano_serie_frequenta_memb', 'cod_curso_frequentou_pessoa_memb',
#        'cod_ano_serie_frequentou_memb', 'cod_concluiu_frequentou_memb',
#        'cod_trabalhou_memb', 'cod_afastado_trab_memb',
#        'cod_agricultura_trab_memb', 'cod_principal_trab_memb',
#        'cod_trabalho_12_meses_memb', 'qtd_meses_12_meses_memb', 'peso.pes'],
#       dtype='object')

# %%
contagem_pessoas = df_fam_pessoas_amostra_100mil_limpa.groupby('id_familia')['id_pessoa'].nunique().reset_index()

# %%
# Avaliando se alguma família ficou com o número de pessoas menor do que o previsto no campo qtd_pessoas

# 1. Contar o número de IDs de pessoas diferentes para cada 'id_familia'
contagem_pessoas = df_fam_pessoas_amostra_100mil_limpa.groupby('id_familia')['id_pessoa'].nunique().reset_index()

# Renomear a coluna para algo mais descritivo
contagem_pessoas.rename(columns={'id_pessoa': 'num_id_pessoas'}, inplace=True)

# 2. Juntar os dados da contagem com o dataframe original
# Supondo que 'qtde_pessoas' esteja no mesmo dataframe e corresponda ao 'id_familia'
resultado_comparacao = pd.merge(contagem_pessoas, df_fam_pessoas_amostra_100mil_limpa[['id_familia', 'qtde_pessoas']],
                                 on='id_familia', how='left')

# 3. Comparar os valores
resultado_comparacao['diferenca'] = resultado_comparacao['qtde_pessoas'] - resultado_comparacao['num_id_pessoas']

# Exibir os resultados
print(resultado_comparacao[['id_familia', 'qtde_pessoas', 'num_id_pessoas', 'diferenca']].head(10))

# Opcional: Analisar quantas famílias têm diferença nos números
familias_com_diferenca = resultado_comparacao[resultado_comparacao['diferenca'] != 0]
print(f"Número de famílias com diferença: {len(familias_com_diferenca)}")
# Out:
#    id_familia  qtde_pessoas  num_id_pessoas  diferenca
# 0           1             5               5          0
# 1           1             5               5          0
# 2           1             5               5          0
# 3           1             5               5          0
# 4           1             5               5          0
# 5           3             5               5          0
# 6           3             5               5          0
# 7           3             5               5          0
# 8           3             5               5          0
# 9           3             5               5          0
# Número de famílias com diferença: 278489

# %%
# 1. Identificar as id_familia com diferença > 0
id_familias_com_diferenca = resultado_comparacao[resultado_comparacao['diferenca'] > 0]['id_familia']

# 2. Excluir essas id_familia do dataframe original
df_fam_pessoas_amostra_100mil_limpa = df_fam_pessoas_amostra_100mil_limpa[~df_fam_pessoas_amostra_100mil_limpa['id_familia'].isin(id_familias_com_diferenca)]

# 3. Exibir o número de linhas restantes após a exclusão
numero_linhas_restantes = df_fam_pessoas_amostra_100mil_limpa.shape[0]
print(f"Número de linhas restantes após excluir famílias com diferença > 0: {numero_linhas_restantes}")
# Out:
# Número de linhas restantes após excluir famílias com diferença > 0: 7658325

# %%
df_fam_pessoas_amostra_100mil_limpa.head()
# Out:
#    cd_ibge  uf_ibge  regiao_ibge  estrato  classf  id_familia  \
# 0  4212908       42            4        1       2      268503
# 1  4212908       42            4        1       2      268503
# 2  4212908       42            4        1       2      268503
# 3  4212908       42            4        1       2      268503
# 4  2931905       29            2        2       3     2888440
#
#    vlr_renda_media_fam  cod_local_domic_fam  cod_especie_domic_fam  \
# 0                 60.0                  1.0                    1.0
# 1                 60.0                  1.0                    1.0
# 2                 60.0                  1.0                    1.0
# 3                 60.0                  1.0                    1.0
# 4                  0.0                  2.0                    1.0
#
#    qtd_comodos_domic_fam  ...  cod_curso_frequentou_pessoa_memb  \
# 0                    5.0  ...                              -1.0
# 1                    5.0  ...                              -1.0
# 2                    5.0  ...                              -1.0
# 3                    5.0  ...                               4.0
# 4                    2.0  ...                              -1.0
#
#    cod_ano_serie_frequentou_memb  cod_concluiu_frequentou_memb  \
# 0                           -1.0                          -1.0
# 1                           -1.0                          -1.0
# 2                           -1.0                          -1.0
# 3                            4.0                           1.0
# 4                           -1.0                          -1.0
#
#    cod_trabalhou_memb  cod_afastado_trab_memb  cod_agricultura_trab_memb  \
# 0                -1.0                    -1.0                       -1.0
# 1                 2.0                     2.0                       -1.0
# 2                -1.0                    -1.0                       -1.0
# 3                 1.0                    -1.0                        1.0
# 4                -1.0                    -1.0                       -1.0
#
#    cod_principal_trab_memb  cod_trabalho_12_meses_memb  \
# 0                     -1.0                        -1.0
# 1                     -1.0                         2.0
# 2                     -1.0                        -1.0
# 3                      6.0                         1.0
# 4                     -1.0                        -1.0
#
#    qtd_meses_12_meses_memb         peso.pes
# 0                     -1.0  563277716385694
# 1                     -1.0  563277716385694
# 2                     -1.0  563277716385694
# 3                     12.0  563277716385694
# 4                     -1.0  563263195326236
#
# [5 rows x 51 columns]

# %%
df_fam_pessoas_amostra_100mil_limpa.shape
# Out:
# (7658325, 51)

# %%
# Identificar IDs de pessoa que se repetem
ids_repetidos = df_fam_pessoas_amostra_100mil_limpa['id_pessoa'][df_fam_pessoas_amostra_100mil_limpa['id_pessoa'].duplicated()]

# Verificar se existem IDs repetidos e exibir o resultado
if not ids_repetidos.empty:
    print(f'Existem IDs de pessoa repetidos. Os IDs repetidos são:\n{ids_repetidos}')
else:
    print('Não existem IDs de pessoa repetidos.')
# Out:
# Existem IDs de pessoa repetidos. Os IDs repetidos são:
# 427724     4
# 3632383    6
# 4406070    1
# 4949633    3
# 4962888    8
# 5077336    1
# 5526126    5
# 6266290    6
# 7171493    9
# Name: id_pessoa, dtype: int64

# %%
#Separando novamente as duas bases

# 1. Listar as colunas que queremos manter de cada dataframe original
colunas_pessoas = df_pessoas_amostra_100mil_limpa.columns.tolist()
colunas_familia = df_fam_amostra_100mil_limpa.columns.tolist()

# 2. Criar um dataframe para as pessoas a partir da base limpa, mantendo apenas as colunas desejadas
df_pessoas_final = df_fam_pessoas_amostra_100mil_limpa[colunas_pessoas]

# 3. Criar um dataframe para as famílias a partir da base limpa, mantendo apenas as colunas desejadas
df_familia_final = df_fam_pessoas_amostra_100mil_limpa[colunas_familia]

# %%
df_pessoas_final.head()
# Out:
#    id_familia  id_pessoa  cod_sexo_pessoa  idade  cod_parentesco_rf_pessoa  \
# 0      268503    2351897                2      4                         3
# 1      268503    2578989                2     15                         3
# 2      268503    3312847                2     13                         3
# 3      268503   10482075                2     38                         1
# 4     2888440    5553031                2      5                         3
#
#    cod_raca_cor_pessoa  cod_local_nascimento_pessoa  \
# 0                  1.0                          2.0
# 1                  1.0                          1.0
# 2                  1.0                          1.0
# 3                  1.0                          2.0
# 4                  4.0                          2.0
#
#    cod_certidao_registrada_pessoa  cod_deficiencia_memb  \
# 0                               1                     2
# 1                               1                     2
# 2                               1                     2
# 3                               1                     2
# 4                               1                     2
#
#    cod_sabe_ler_escrever_memb  ...  cod_curso_frequentou_pessoa_memb  \
# 0                         2.0  ...                              -1.0
# 1                         1.0  ...                              -1.0
# 2                         2.0  ...                              -1.0
# 3                         1.0  ...                               4.0
# 4                         2.0  ...                              -1.0
#
#    cod_ano_serie_frequentou_memb  cod_concluiu_frequentou_memb  \
# 0                           -1.0                          -1.0
# 1                           -1.0                          -1.0
# 2                           -1.0                          -1.0
# 3                            4.0                           1.0
# 4                           -1.0                          -1.0
#
#    cod_trabalhou_memb  cod_afastado_trab_memb  cod_agricultura_trab_memb  \
# 0                -1.0                    -1.0                       -1.0
# 1                 2.0                     2.0                       -1.0
# 2                -1.0                    -1.0                       -1.0
# 3                 1.0                    -1.0                        1.0
# 4                -1.0                    -1.0                       -1.0
#
#    cod_principal_trab_memb  cod_trabalho_12_meses_memb  \
# 0                     -1.0                        -1.0
# 1                     -1.0                         2.0
# 2                     -1.0                        -1.0
# 3                      6.0                         1.0
# 4                     -1.0                        -1.0
#
#    qtd_meses_12_meses_memb         peso.pes
# 0                     -1.0  563277716385694
# 1                     -1.0  563277716385694
# 2                     -1.0  563277716385694
# 3                     12.0  563277716385694
# 4                     -1.0  563263195326236
#
# [5 rows x 24 columns]

# %%
df_familia_final.head()
# Out:
#    cd_ibge  uf_ibge  regiao_ibge  estrato  classf  id_familia  \
# 0  4212908       42            4        1       2      268503
# 1  4212908       42            4        1       2      268503
# 2  4212908       42            4        1       2      268503
# 3  4212908       42            4        1       2      268503
# 4  2931905       29            2        2       3     2888440
#
#    vlr_renda_media_fam  cod_local_domic_fam  cod_especie_domic_fam  \
# 0                 60.0                  1.0                    1.0
# 1                 60.0                  1.0                    1.0
# 2                 60.0                  1.0                    1.0
# 3                 60.0                  1.0                    1.0
# 4                  0.0                  2.0                    1.0
#
#    qtd_comodos_domic_fam  ...  cod_iluminacao_domic_fam  \
# 0                    5.0  ...                       1.0
# 1                    5.0  ...                       1.0
# 2                    5.0  ...                       1.0
# 3                    5.0  ...                       1.0
# 4                    2.0  ...                       1.0
#
#    cod_calcamento_domic_fam  cod_familia_indigena_fam  \
# 0                       1.0                       2.0
# 1                       1.0                       2.0
# 2                       1.0                       2.0
# 3                       1.0                       2.0
# 4                       3.0                       2.0
#
#    ind_familia_quilombola_fam  ind_parc_mds_fam  qtde_pessoas  \
# 0                         2.0               0.0             4
# 1                         2.0               0.0             4
# 2                         2.0               0.0             4
# 3                         2.0               0.0             4
# 4                         2.0               0.0             2
#
#           peso.fam  dias_cadastramento  dias_atualizacao  classe_renda
# 0    5502526707828              5128.0               102           0.0
# 1    5502526707828              5128.0               102           0.0
# 2    5502526707828              5128.0               102           0.0
# 3    5502526707828              5128.0               102           0.0
# 4  550282046697327              2646.0               151           0.0
#
# [5 rows x 28 columns]

# %%
# Identificar IDs de familia que se repetem
ids_repetidos = df_familia_final['id_familia'][df_familia_final['id_familia'].duplicated()]

# Verificar se existem IDs repetidos e exibir o resultado
if not ids_repetidos.empty:
    print(f'Existem IDs de familia repetidos. Os IDs repetidos são:\n{ids_repetidos}')
else:
    print('Não existem IDs de familia repetidos.')
# Out:
# Existem IDs de familia repetidos. Os IDs repetidos são:
# 1           268503
# 2           268503
# 3           268503
# 5          2888440
# 7          2113517
#             ...
# 7936808    4378731
# 7936809    4378731
# 7936811    4616178
# 7936812    4616178
# 7936813    4616178
# Name: id_familia, Length: 4763557, dtype: int64

# %%
# 1. Identificar os IDs de família que se repetem
familias_repetidas = df_familia_final['id_familia'][df_familia_final['id_familia'].duplicated(keep=False)]

# 2. Filtrar o dataframe para mostrar todas as colunas dos casos de famílias repetidas
casos_familias_repetidas = df_familia_final[df_familia_final['id_familia'].isin(familias_repetidas)]

# 3. Exibir o resultado (todas as colunas dos casos repetidos)
casos_familias_repetidas.head()
# Out:
#    cd_ibge  uf_ibge  regiao_ibge  estrato  classf  id_familia  \
# 0  4212908       42            4        1       2      268503
# 1  4212908       42            4        1       2      268503
# 2  4212908       42            4        1       2      268503
# 3  4212908       42            4        1       2      268503
# 4  2931905       29            2        2       3     2888440
#
#    vlr_renda_media_fam  cod_local_domic_fam  cod_especie_domic_fam  \
# 0                 60.0                  1.0                    1.0
# 1                 60.0                  1.0                    1.0
# 2                 60.0                  1.0                    1.0
# 3                 60.0                  1.0                    1.0
# 4                  0.0                  2.0                    1.0
#
#    qtd_comodos_domic_fam  ...  cod_iluminacao_domic_fam  \
# 0                    5.0  ...                       1.0
# 1                    5.0  ...                       1.0
# 2                    5.0  ...                       1.0
# 3                    5.0  ...                       1.0
# 4                    2.0  ...                       1.0
#
#    cod_calcamento_domic_fam  cod_familia_indigena_fam  \
# 0                       1.0                       2.0
# 1                       1.0                       2.0
# 2                       1.0                       2.0
# 3                       1.0                       2.0
# 4                       3.0                       2.0
#
#    ind_familia_quilombola_fam  ind_parc_mds_fam  qtde_pessoas  \
# 0                         2.0               0.0             4
# 1                         2.0               0.0             4
# 2                         2.0               0.0             4
# 3                         2.0               0.0             4
# 4                         2.0               0.0             2
#
#           peso.fam  dias_cadastramento  dias_atualizacao  classe_renda
# 0    5502526707828              5128.0               102           0.0
# 1    5502526707828              5128.0               102           0.0
# 2    5502526707828              5128.0               102           0.0
# 3    5502526707828              5128.0               102           0.0
# 4  550282046697327              2646.0               151           0.0
#
# [5 rows x 28 columns]

# %%
# Ajuste para garantir que cada 'id_familia' apareça apenas uma vez no df_familia_final

# 1. Listar as colunas que queremos manter de cada dataframe original
colunas_pessoas = df_pessoas_amostra_100mil_limpa.columns.tolist()
colunas_familia = df_fam_amostra_100mil_limpa.columns.tolist()

# 2. Criar um dataframe para as pessoas a partir da base limpa, mantendo apenas as colunas desejadas
df_pessoas_final = df_fam_pessoas_amostra_100mil_limpa[colunas_pessoas]

# 3. Criar um dataframe para as famílias a partir da base limpa, mantendo apenas as colunas desejadas
# Utilizar drop_duplicates para garantir que cada 'id_familia' apareça apenas uma vez
df_familia_final = df_fam_pessoas_amostra_100mil_limpa[colunas_familia].drop_duplicates(subset=['id_familia'])

# Exibir o número de linhas restantes após a remoção de duplicados
print(f"Número de famílias no dataframe final: {df_familia_final.shape[0]}")
# Out:
# Número de famílias no dataframe final: 2894768

# %%
# Identificar IDs de pessoa que se repetem
ids_repetidos = df_pessoas_final['id_pessoa'][df_pessoas_final['id_pessoa'].duplicated()]

# Verificar se existem IDs repetidos e exibir o resultado
if not ids_repetidos.empty:
    print(f'Existem IDs de pessoa repetidos. Os IDs repetidos são:\n{ids_repetidos}')
else:
    print('Não existem IDs de pessoa repetidos.')
# Out:
# Existem IDs de pessoa repetidos. Os IDs repetidos são:
# 427724     4
# 3632383    6
# 4406070    1
# 4949633    3
# 4962888    8
# 5077336    1
# 5526126    5
# 6266290    6
# 7171493    9
# Name: id_pessoa, dtype: int64

# %%
# Exibir o número de linhas restantes após a limpeza da base de pessoas
print(f"Número de pessoas no dataframe final: {df_pessoas_final.shape[0]}")
# Out:
# Número de pessoas no dataframe final: 7658325

# %%
# Identificar IDs de familia que se repetem
ids_repetidos = df_familia_final['id_familia'][df_familia_final['id_familia'].duplicated()]

# Verificar se existem IDs repetidos e exibir o resultado
if not ids_repetidos.empty:
    print(f'Existem IDs de familia repetidos. Os IDs repetidos são:\n{ids_repetidos}')
else:
    print('Não existem IDs de familia repetidos.')
# Out:
# Não existem IDs de familia repetidos.

# %%
# Salvar o dataframe df_pessoas_amostra_100mil_limpa em um arquivo CSV com o nome desejado
df_fam_pessoas_amostra_100mil_limpa.to_csv('df_familia_pessoa_final.csv', index=False)

# %%
df_familia_final.isnull().sum()
# Out:
# cd_ibge                          0
# uf_ibge                          0
# regiao_ibge                      0
# estrato                          0
# classf                           0
# id_familia                       0
# vlr_renda_media_fam              0
# cod_local_domic_fam              0
# cod_especie_domic_fam            0
# qtd_comodos_domic_fam            0
# qtd_comodos_dormitorio_fam       0
# cod_material_piso_fam            0
# cod_material_domic_fam           0
# cod_agua_canalizada_fam          0
# cod_abaste_agua_domic_fam        0
# cod_banheiro_domic_fam           0
# cod_escoa_sanitario_domic_fam    0
# cod_destino_lixo_domic_fam       0
# cod_iluminacao_domic_fam         0
# cod_calcamento_domic_fam         0
# cod_familia_indigena_fam         0
# ind_familia_quilombola_fam       0
# ind_parc_mds_fam                 0
# qtde_pessoas                     0
# peso.fam                         0
# dias_cadastramento               0
# dias_atualizacao                 0
# classe_renda                     0
# dtype: int64

# %%
df_pessoas_final.isnull().sum()
# Out:
# id_familia                          0
# id_pessoa                           0
# cod_sexo_pessoa                     0
# idade                               0
# cod_parentesco_rf_pessoa            0
# cod_raca_cor_pessoa                 0
# cod_local_nascimento_pessoa         0
# cod_certidao_registrada_pessoa      0
# cod_deficiencia_memb                0
# cod_sabe_ler_escrever_memb          0
# ind_frequenta_escola_memb           0
# cod_escola_local_memb               0
# cod_curso_frequenta_memb            0
# cod_ano_serie_frequenta_memb        0
# cod_curso_frequentou_pessoa_memb    0
# cod_ano_serie_frequentou_memb       0
# cod_concluiu_frequentou_memb        0
# cod_trabalhou_memb                  0
# cod_afastado_trab_memb              0
# cod_agricultura_trab_memb           0
# cod_principal_trab_memb             0
# cod_trabalho_12_meses_memb          0
# qtd_meses_12_meses_memb             0
# peso.pes                            0
# dtype: int64

# %%
# Salvando os arquivos finais de df_familia_final e df_pessoa_final
df_familia_final.to_csv('df_familia_final.csv', index=False)
df_pessoas_final.to_csv('df_pessoas_final.csv', index=False)
