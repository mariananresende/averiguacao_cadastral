# %%
import pandas as pd

# Função para adicionar resultados de cada modelo ao dataframe
def adicionar_resultados(modelo, descricao, scores_cv, acuracia_media, precision_0, recall_0, f1_0, 
                         precision_1, recall_1, f1_1, precision_2, recall_2, f1_2, 
                         acuracia_final):
    resultados.append({
        "Modelo": modelo,
        "Descrição": descricao,
        "CV Score 1": scores_cv[0],
        "CV Score 2": scores_cv[1],
        "CV Score 3": scores_cv[2],
        "CV Score 4": scores_cv[3],
        "CV Score 5": scores_cv[4],
        "Acurácia Média": acuracia_media,
        "Precision Classe 0": precision_0,
        "Recall Classe 0": recall_0,
        "F1-Score Classe 0": f1_0,
        "Precision Classe 1": precision_1,
        "Recall Classe 1": recall_1,
        "F1-Score Classe 1": f1_1,
        "Precision Classe 2": precision_2,
        "Recall Classe 2": recall_2,
        "F1-Score Classe 2": f1_2,
        "Acurácia Final": acuracia_final
    })

# %%
# Adição dos resultados de cada modelo

# Lista global para armazenar resultados
resultados = []

adicionar_resultados(
    modelo="Logistic",
    descricao="Variáveis normalizadas e categóricas transformadas usando OneHotEncoder, target classe_renda balanceada",
    scores_cv=[0.7103377, 0.70568864, 0.71438719, 0.70411985, 0.70993155],
    acuracia_media=0.7088929868740194,
    precision_0=0.71, recall_0=0.79, f1_0=0.75,
    precision_1=0.64, recall_1=0.55, f1_1=0.59,
    precision_2=0.76, recall_2=0.78, f1_2=0.77,
    acuracia_final=0.7078878041221137
)

adicionar_resultados(
    modelo="KNN",
    descricao="Variáveis normalizadas e categóricas transformadas usando OneHotEncoder, target classe_renda balanceada",
    scores_cv=[0.62904371, 0.63039969, 0.6327005, 0.62824487, 0.63102157],
    acuracia_media=0.6302820684049575,
    precision_0=0.62, recall_0=0.73, f1_0=0.67,
    precision_1=0.53, recall_1=0.47, f1_1=0.50,
    precision_2=0.75, recall_2=0.69, f1_2=0.72,
    acuracia_final=0.6322124076656852
)

adicionar_resultados(
    modelo='Decision Tree',
    descricao="Variáveis normalizadas e categóricas transformadas usando OneHotEncoder, target classe_renda balanceada",
    scores_cv=[0.64789824, 0.65228902, 0.65233114, 0.65110422, 0.65207284],
    acuracia_media=0.6511390909562984,
    precision_0=0.67, recall_0=0.67, f1_0=0.67,
    precision_1=0.55, recall_1=0.56, f1_1=0.56,
    precision_2=0.71, recall_2=0.71, f1_2=0.71,
    acuracia_final=0.6478123870034609
)

adicionar_resultados(
    modelo='Random Forest',
    descricao="Variáveis normalizadas e categóricas transformadas usando OneHotEncoder, target classe_renda balanceada",
    scores_cv=[0.74475366, 0.74365597, 0.74815963, 0.7396358, 0.7429291],
    acuracia_media=0.7438268318528491,
    precision_0=0.76, recall_0=0.79, f1_0=0.77,
    precision_1=0.67, recall_1=0.66, f1_1=0.66,
    precision_2=0.80, recall_2=0.78, f1_2=0.79,
    acuracia_final=0.7442533188697763
)

adicionar_resultados(
    modelo='XGBoost',
    descricao="Variáveis normalizadas e categóricas transformadas usando OneHotEncoder, target classe_renda balanceada",
    scores_cv=[0.75095241, 0.7518564,  0.75442335, 0.74512463, 0.7542942],
    acuracia_media=0.7513301974840838,
    precision_0=0.76, recall_0=0.80, f1_0=0.78,
    precision_1=0.69, recall_1=0.66, f1_1=0.68,
    precision_2=0.81, recall_2=0.80, f1_2=0.80,
    acuracia_final=0.755204297742652
)

adicionar_resultados(
    modelo='CatBoost',
    descricao="Variáveis normalizadas e categóricas transformadas usando OneHotEncoder, target classe_renda balanceada",
    scores_cv=[0.75392264, 0.75753858, 0.76068707, 0.75022601, 0.75584399],
    acuracia_media=0.7556436592893512,
    precision_0=0.77, recall_0=0.81, f1_0=0.79,
    precision_1=0.69, recall_1=0.66, f1_1=0.68,
    precision_2=0.81, recall_2=0.80, f1_2=0.80,
    acuracia_final=0.7574771424143809)


# Criando o DataFrame
df_resultados_1 = pd.DataFrame(resultados)

# %% [markdown]
# ## Adicionando os resultados no mesmo df

# %%
# Adição dos resultados de cada modelo

# Lista para armazenar os resultados de cada modelo
resultados = []
    
adicionar_resultados(
    modelo="Logistic",
    descricao="Amostra 10mil linhas, variáveis normalizadas e categóricas transformadas usando OneHotEncoder, target classe_renda balanceada",
    scores_cv=[0.71375,  0.68625,  0.699375, 0.71, 0.706875],
    acuracia_media=0.7032499999999999,
    precision_0=0.70, recall_0=0.78, f1_0=0.74,
    precision_1=0.60, recall_1=0.49, f1_1=0.54,
    precision_2=0.73, recall_2=0.78, f1_2=0.76,
    acuracia_final=0.685
)

adicionar_resultados(
    modelo='KNN',
    descricao="Amostra 10mil linhas, variáveis normalizadas e categóricas transformadas usando OneHotEncoder, target classe_renda balanceada",
    scores_cv=[0.584375, 0.575, 0.579375, 0.613125, 0.5975],
    acuracia_media=0.5898749999999999,
    precision_0=0.58, recall_0=0.65, f1_0=0.62,
    precision_1=0.47, recall_1=0.43, f1_1=0.45,
    precision_2=0.71, recall_2=0.68, f1_2=0.69,
    acuracia_final=0.5905
)

adicionar_resultados(
    modelo='Decision Tree',
    descricao="Amostra 10mil linhas, variáveis normalizadas e categóricas transformadas usando OneHotEncoder, target classe_renda balanceada",
    scores_cv=[0.62625,  0.616875, 0.628125, 0.625625, 0.64125],
    acuracia_media=0.627625,
    precision_0=0.67, recall_0=0.67, f1_0=0.67,
    precision_1=0.54, recall_1=0.54, f1_1=0.54, 
    precision_2=0.70, recall_2=0.69, f1_2=0.70, 
    acuracia_final=0.6365
)

adicionar_resultados(
    modelo='Random Forest',
    descricao="Amostra 10mil linhas, variáveis normalizadas e categóricas transformadas usando OneHotEncoder, target classe_renda balanceada",
    scores_cv=[0.726875, 0.71375,  0.705625, 0.730625, 0.72125],
    acuracia_media=0.719625,
    precision_0=0.74, recall_0=0.80, f1_0=0.77,       
    precision_1=0.67, recall_1=0.62, f1_1=0.64,  
    precision_2=0.78, recall_2=0.78, f1_2=0.78,  
    acuracia_final=0.733
)

adicionar_resultados(
    modelo='XGBoost',
    descricao="Amostra 10mil linhas, variáveis normalizadas e categóricas transformadas usando OneHotEncoder, target classe_renda balanceada",
    scores_cv=[0.729375, 0.705625, 0.72375,  0.721875, 0.735625],
    acuracia_media=0.72325,
    precision_0=0.73, recall_0=0.78, f1_0=0.75,    
    precision_1=0.65, recall_1=0.61, f1_1=0.63,   
    precision_2=0.77, recall_2=0.78, f1_2=0.78,    
    acuracia_final=0.7205
)

adicionar_resultados(
    modelo='CatBoost',
    descricao="Amostra 10mil linhas, variáveis normalizadas e categóricas transformadas usando OneHotEncoder, target classe_renda balanceada",
    scores_cv=[0.7375,   0.70875,  0.708125, 0.733125, 0.735],
    acuracia_media=0.7245,
    precision_0=0.75, recall_0=0.79, f1_0=0.77, 
    precision_1=0.67, recall_1=0.62, f1_1=0.64, 
    precision_2=0.77, recall_2=0.79, f1_2=0.78, 
    acuracia_final=0.733
)

# Depois, criar o DataFrame e salvar novamente, caso queira continuar adicionando mais tarde.
df_resultados_2 = pd.DataFrame(resultados)

# %%
# Adição dos resultados de cada modelo

# Lista para armazenar os resultados de cada modelo
resultados = []
    
adicionar_resultados(
    modelo="Decision Tree",
    descricao="Variáveis apenas normalizadas, target classe_renda balanceada",
    scores_cv=[0.65241816, 0.64647769, 0.65452667, 0.64710061, 0.64806922],
    acuracia_media=0.649718469639053,
    precision_0=0.68, recall_0=0.67, f1_0=0.68,
    precision_1=0.56, recall_1=0.56, f1_1=0.56,
    precision_2=0.72, recall_2=0.72, f1_2=0.72,
    acuracia_final=0.6512216540110543
)


adicionar_resultados(
    modelo='Random Forest',
    descricao="Variáveis apenas normalizadas, target classe_renda balanceada",
    scores_cv=[0.74417253, 0.74501195, 0.74912824, 0.74338112, 0.74602867],
    acuracia_media=0.745544502331431,
    precision_0=0.76, recall_0=0.79, f1_0=0.78,
    precision_1=0.67, recall_1=0.66, f1_1=0.67, 
    precision_2=0.80, recall_2=0.79, f1_2=0.80, 
    acuracia_final=00.7469910635879953
)

adicionar_resultados(
    modelo='XGBoost',
    descricao="Variáveis apenas normalizadas, target classe_renda balanceada",
    scores_cv=[0.75398722, 0.75573061, 0.75577941, 0.74886995, 0.75552112],
    acuracia_media=0.7539776608830188,
    precision_0=0.76, recall_0=0.80, f1_0=0.78, 
    precision_1=0.68, recall_1=0.66, f1_1=0.67,
    precision_2=0.81, recall_2=0.80, f1_2=0.80, 
    acuracia_final=0.7531380753138075
)

adicionar_resultados(
    modelo='CatBoost',
    descricao="Variáveis apenas normalizadas, target classe_renda balanceada",
    scores_cv=[0.7531478,  0.75469749, 0.75739378, 0.75267984, 0.7568126 ],
    acuracia_media=0.754946301881834,
    precision_0=0.77, recall_0=0.80, f1_0=0.79,  
    precision_1=0.69, recall_1=0.66, f1_1=0.68, 
    precision_2=0.81, recall_2=0.80, f1_2=0.80,
    acuracia_final=0.75659899788212
)

# Depois, criar o DataFrame e salvar novamente, caso queira continuar adicionando mais tarde.
df_resultados_3 = pd.DataFrame(resultados)

# %%
# Concatenando os resultados
df_resultados_final = pd.concat([df_resultados_1, df_resultados_2, df_resultados_3], ignore_index=True)

# %%
# Estilizando o DataFrame
styled_df = df_resultados_final.style.apply(
    lambda x: ['background-color: #f9f9f9' for i in range(len(x))], axis=0
).set_table_styles([
    {
        'selector': 'td',  # Aplica a todos os elementos da célula
        'props': [('padding', '10px'), ('border', '2px solid black')]  # Define o espaço interno e a borda
    },
    {
        'selector': 'th',  # Aplica também aos cabeçalhos
        'props': [('padding', '10px'), ('border', '2px solid black')]
    }
])

# %%
styled_df
# Out:
# <style type="text/css">
# #T_3a3f2 td {
#   padding: 10px;
#   border: 2px solid black;
# }
# #T_3a3f2 th {
#   padding: 10px;
#   border: 2px solid black;
# }
# ...

# %%
df_resultados_final.head(20)
# Out:
#            Modelo                                          Descrição  \
# 0        Logistic  Variáveis normalizadas e categóricas transform...
# 1             KNN  Variáveis normalizadas e categóricas transform...
# 2   Decision Tree  Variáveis normalizadas e categóricas transform...
# 3   Random Forest  Variáveis normalizadas e categóricas transform...
# 4         XGBoost  Variáveis normalizadas e categóricas transform...
# 5        CatBoost  Variáveis normalizadas e categóricas transform...
# 6        Logistic  Amostra 10mil linhas, variáveis normalizadas e...
# 7             KNN  Amostra 10mil linhas, variáveis normalizadas e...
# 8   Decision Tree  Amostra 10mil linhas, variáveis normalizadas e...
# 9   Random Forest  Amostra 10mil linhas, variáveis normalizadas e...
# 10        XGBoost  Amostra 10mil linhas, variáveis normalizadas e...
# 11       CatBoost  Amostra 10mil linhas, variáveis normalizadas e...
# 12  Decision Tree  Variáveis apenas normalizadas, target classe_r...
# ...
