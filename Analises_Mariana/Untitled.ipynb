# %%
import pandas as pd

# %%
# Carregar o dataframe
df_pessoas_final_2 = pd.read_csv('../Data/df_pessoas_final_2.csv')

# %%
df_pessoas_final_2.head()
# Out:
#    id_familia  id_pessoa  cod_sexo_pessoa  idade  cod_parentesco_rf_pessoa  \
# 0     2297048    5080082                2     24                         1
# 1     2297048    6871939                2      5                         3
# 2     2297048   12839729                1      2                         3
# 3      697587    4991136                1     84                         1
# 4     3807697    1628136                2     24                         1
#
#    cod_raca_cor_pessoa  cod_local_nascimento_pessoa  \
# 0                  4.0                          2.0
# 1                  4.0                          2.0
# 2                  4.0                          2.0
# 3                  4.0                          1.0
# 4                  4.0                          2.0
#
#    cod_certidao_registrada_pessoa  cod_deficiencia_memb  \
# 0                               1                     2
# 1                               1                     2
# ...

# %%
# Incluindo a coluna calsse_renda no df_pessoas_final
# Carregar o arquivo CSV 
df_familia_final_2 = pd.read_csv('../Data/df_familia_final_2.csv')

# %%
df_familia_final_2.head()
# Out:
#    cd_ibge  uf_ibge  regiao_ibge  estrato  classf  id_familia  \
# 0  2708501       27            2        2       3     2297048
# 1  2516607       25            2        1       3      697587
# 2  2312908       23            2        2       3     3807697
# 3  2911709       29            2        2       3     3322305
# 4  3168705       31            3        2       2     1891054
#
#    vlr_renda_media_fam  cod_local_domic_fam  cod_especie_domic_fam  \
# 0                 40.0                  1.0                    1.0
# 1                937.0                  2.0                    1.0
# 2                 66.0                  1.0                    1.0
# 3                636.0                  1.0                    1.0
# 4                200.0                  1.0                    1.0
#
#    qtd_comodos_domic_fam  ...  cod_iluminacao_domic_fam  \
# 0                    5.0  ...                       1.0
# 1                    6.0  ...                       1.0
# ...

# %%
# Realizar o merge entre df_pessoas_final e df_familia_final para adicionar a coluna 'classe_renda'
# Usando a coluna 'id_familia' como chave para associar
df_pessoas_final_2 = df_pessoas_final_2.merge(
    df_familia_final_2[['id_familia', 'classe_renda']],
    on='id_familia',
    how='left'
)

# Verificar se o merge foi realizado corretamente e se a coluna 'classe_renda' está presente
print(f"Número de pessoas no dataframe final: {df_pessoas_final_2.shape[0]}")
print(f"Número de valores nulos na coluna 'classe_renda': {df_pessoas_final_2['classe_renda'].isnull().sum()}")
df_pessoas_final.head()
